# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy
# %matplotlib inline

# %%
from sympy.parsing.sympy_parser import parse_expr, eval_expr
from sympy.utilities import lambdify
from sympy import Symbol

# %%
ex = parse_expr("1/(1+exp(-x))")
dex = ex.diff('x')
d2ex = ex.diff('x', 2)
d3ex = ex.diff('x', 3)

# %%
print('ex:', ex)
print('dex:', dex)
print('d2ex:', d2ex)
print('d3ex:', d3ex)
# Out:
# ex: 1/(1 + exp(-x))
# dex: exp(-x)/(1 + exp(-x))**2
# d2ex: (-1 + 2*exp(-x)/(1 + exp(-x)))*exp(-x)/(1 + exp(-x))**2
# d3ex: (1 - 6*exp(-x)/(1 + exp(-x)) + 6*exp(-2*x)/(1 + exp(-x))**2)*exp(-x)/(1 + exp(-x))**2

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.01)

# %%
ex_mas = lambdify(Symbol('x'), ex, 'numpy')(x)
dex_mas = lambdify(Symbol('x'), dex, 'numpy')(x)
d2ex_mas = lambdify(Symbol('x'), d2ex, 'numpy')(x)
d3ex_mas = lambdify(Symbol('x'), d3ex, 'numpy')(x)

# %%
def plot(input_list):
    for x, y, label in input_list:
        plt.figure()
        plt.plot(x, y, label=label);
        plt.legend()

# %%
input_list = [[x, ex_mas, 'ex_mas'], 
              [x, dex_mas, 'dex_mas'], 
              [x, d2ex_mas, 'd2ex_mas'], 
              [x, d3ex_mas, 'd3ex_mas']]
plot(input_list)

# %%
parse_expr(r"diff(a**3, a)")
# Out:
# 3*a**2

# %%
# parse_expr("solve(a**2 + 2*a + 1 = 0, a)")

# %%
# ex = parse_expr(r"diff(((a-2)**2+(a-4)**2+(a-1)**2)**0.5, a)")
# new_ex_str = "solve("+str(ex)+", a)"
# print(new_ex_str)
# ex_solve = eval_expr(new_ex_str, {'a': Symbol('a')}, {'a': Symbol('a')})
